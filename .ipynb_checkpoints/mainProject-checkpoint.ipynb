# %% [markdown]
# # A Mini Datasheet of Covid-19 Clinical Trials Dataset Using Microsoft Datasheets for Datasets Framework

# %% [markdown]
# ### By: Diego Cardenas & Kiran Treacy

# %% [markdown]
# ## Abstract

# %% [markdown]
#  In this final project, we analyzed the COVID-19 Clinical Trials dataset obtained from Kaggle using the Microsoft Datasheets for Datasets framework. This approach provided a structured method for evaluating how the dataset was collected, processed, and documented. By using the datasheet items, we show how to properly analyze real world data while also identifying the ethical considerations, limits, and risks associated with its use. This project will be considered a mini datasheet including a highlighted importance of transparency, data handling, and ethical reasoning.

# %% [markdown]
# ## Introduction and Background

# %% [markdown]
# The COVID-19 pandemic was one of the most global scientific efforts ever. Researchers around the world conducted many clinical trials to test vaccines and treatments. These trials produced an enormous amount of data. Most of it became publicly accessible. So, we can analyze this COVID-19 trial data such as how the data was collected? How was it processed? And whether it can be responsibly used.
#
# We are exploring the COVID-19 Clinical Trials dataset using the items of Microsoft Datasheets for Datasets framework. We are looking for the dataset’s origins, limits, ethical concerns, and potential biases. This is important because companies will use datasheet items to analyze datasets like these, especially human subjects, often containing hidden issues that can affect the accuracy and fairness of the conclusions made.
#
# Everyone should be interested in this analysis because COVID-19 impacted everyone in the world. So checking this dataset's reliability, fairness, and accuracy will make sure that we can depend on the items in the datasheet so that the data in the dataset that anyone can have access to is reliable.

# %% [markdown]
# ## Data Collection Considerations Using the Microsoft Datasheet Format

# %% [markdown]
# <b> Motivation for Dataset Creation? Why was the dataset created? (e.g., were there specific
# tasks in mind, or a specific gap that needed to be filled?) <b>
#
# The dataset displayed on Kaggle was created by Parul Pandey and was compiled from ClinicalTrials.gov, a public registry created by the U.S. Government Law to provide transparency in clinical research. This specific collection of COVID-19 trials was probably assembled to track and analyze the global research response to the pandemic.
# What (other) tasks could the dataset be used for? Are there obvious tasks for which it should not be used?
#
#
# <b>What (other) tasks could the dataset be used for? Are there obvious tasks for which it should not be used?<b>
#
# It could be used for meta-research and medical studies. It should not be used to make personal medical decisions without consulting a doctor.
#
# <b>Has the dataset been used for any tasks already? If so, where are the results so others can compare (e.g., links to published papers)?<b>
#
# Tons of data from ClinicalTrials.gov including ours is widely used in reviews and research papers analyzing the medical research landscape. The COVID-19 data can be found in multiple papers.
#
# <b>Who funded the creation of the dataset? If there is an associated grant, provide the grant number.<b>
#
# The dataset was compiled from ClinicalTrials.gov, which is funeded and maintained by the U.S. National Library of Medicine (NLM) and the National Institutes of Health (NIH).

# %% [markdown]
# ## Dataset's Composition

# %% [markdown]
# <b> What are the instances? (that is, examples; e.g., documents, images, people, countries) Are there multiple types of instances? (e.g., movies, users, ratings; people, interactions between them; nodes, edges)<b>
#
# Instances would be the different trials that are on each row. The instances are all formated the same and may look the same and assume that they are same types of instances but each instance is unique as each trial is unique.
#
# <b>Are relationships between instances made explicit in the data (e.g., social network links, user/movie ratings, etc.)?<b>
#
# The relationships between instances are not explicitly stated. This must be inferred from shared sponsors or IDs.
#
# <b>How many instances of each type are there?<b>
#
# 229 trial records
#
# <b>What data does each instance consist of? “Raw” data (e.g., unprocessed text or images)? Features/attributes?  Is there a label/target associated with instances? If the instances are related to people, are subpopulations identified (e.g., by age, gender, etc.) and what is their distribution?<b>
#
# Structured metadata (not raw data). Includes trial ID, title, status, conditions, interventions, sponsor, locations, dates, participant demographics (age, gender), and links to full records.
#
# <b>Is everything included or does the data rely on external resources? (e.g., websites, tweets, datasets) If external resources, a) are there guarantees that they will exist, and remain constant, over time; b) is there an official archival version. Are there licenses, fees or rights associated with any of the data?<b>
#
# The data is mostly self-contained in the CSV file (trial metadata). However, it relies on external resources such as the URL field for each trial linked to the live, updated record on ClinicalTrials.gov. And the study documents field (e.g., in row 20, 71) contains links to external PDFs like protocols and statistical analysis plans.
#
# <b>Are there recommended data splits or evaluation measures? (e.g., training, development, testing; accuracy/AUC)<b>
#
# No. This is not a benchmark dataset for machine learning. It is a descriptive, real-world registry dataset.
#
# <b>What experiments were initially run on this dataset? Have a summary of those results and, if available, provide the link to a paper with more information here.<b>
#
# This specific CSV file is a snapshot created for analysis or sharing. Therefore, no "initial experiments" were run on this exact file as if it were a released benchmark.
#
# <b>Is the preprocessing software available?<b>
#
# There is no specific "preprocessing software" for this snapshot.
#
# <b>Does this dataset collection/processing procedure achieve the motivation for creating the dataset stated in the first section of this datasheet?<b>
#
# The procedure achieves the stated motivation for a USA COVID-19 analysis, but cannot provide an entire global picture of the COVID-19 clinical research

# %% [markdown]
# ## Data Collection Process

# %% [markdown]
# <b>How was the data collected? (e.g., hardware apparatus/sensor, manual human curation, software program, software interface/API; how were these constructs/measures/methods validated?)<b>
#
# Data was collected by using manual human entry into a structured web-based software program. The ClinicalTrials.gov went through the Protocol Registration and Results System (PRS). The PRS includes automated validation rules.
#
# <b>Who was involved in the data collection process? (e.g.,students, crowdworkers) How were they compensated? (e.g., how much were crowdworkers paid?)<b>
#
# The Kaggle dataset is only a snapshot of COVID-19 clinical trials, created by an individual. The original data is funded by the NIH and NLM. No funding was given to the Kaggle individual.
#
# <b>Over what time-frame was the data collected? Does the collection time-frame match the creation time-frame?<b>
#
# The data for each trial was added and changed over time as the trial progressed. This dataset on Kaggle is just a single copy of the data taken at one specific time-frame. The government data is constantly being updated while the Kaggle file is frozen.
#
# <b>How was the data associated with each instance acquired? Was the data directly observable (e.g., raw text, movie ratings), reported by subjects (e.g., survey responses), or indirectly inferred/derived from other data (e.g., part of speech tags; model-based guesses for age or language)? If the latter two, were they validated/verified and if so how?<b>
#
# The data is self-reported by research teams and put into the ClinicalTrials system. The database managers only only see if the information provided was filled out correctly. Not if it is true. The data is what the researchers report. It is not confirmed information.
#
# <b>Does the dataset contain all possible instances? Or is it, for instance, a sample (not necessarily random) from a larger set of instances?<b>
#
# No. This dataset is a sample from a larger datapool.
#
# <b>If the dataset is a sample, then what is the population? What was the sampling strategy (e.g., deterministic, probabilistic with specific sampling probabilities)? Is the sample representative of the larger set (e.g., geographic coverage)? If not, why not (e.g., to cover a more diverse range of instances)? How does this affect possible uses?<b>
#
# The population is all of the COVID-19 related trials that were registered on ClinicalTrials.gov. The sample strategy was using Kaggle to filter keywords to include every trial on the site about COVID in the USA. The sample is not fully representative of all global COVID research. This means the analyses from the data are best to understand the US COVID research, not the whole world.
#
# <b>Is there information missing from the dataset and why? (this does not include intentionally dropped instances; it might include, e.g., redacted text, withheld documents) Is this data missing because it was unavailable? <b>
#
# Yes, significantly. The Study Results column has an overwhelming amount of "No Results Available." This is the most critical missing information. This is because the trial sponsors did not submit this information to the original government database. Also the creator of the Kaggle dataset looked for words such as “COVID-19” if a study about the virus used a different name, then the search may have missed it. So, some relevant data are absent because it wasn't found by specific keywording.

# %% [markdown]
# ## Dataset Distribution

# %% [markdown]
# <b>How is the dataset distributed? (e.g., website, API, etc.; does the data have a DOI; is it archived redundantly?)<b>
#
# The dataset is distributed by Kaggle which they brought in all different clinical trials to just one dataset.
#
# <b>When will the dataset be released/first distributed? (Is there a canonical paper/reference for this dataset?)<b>
#
# The dataset is unknown by when it was first uploaded to kaggle but we know the last update to it was in April of 2021
#
# <b>What license (if any) is it distributed under? Are there any copyrights on the data?<b>
#
# There is no copyright on this data since in kaggle it is a public database of different datasets for the public and the US gov has another database of individual clinical trials for public use.
#
# <b>Are there any fees or access/export restrictions?<b>
#
# No, there are no fees to access the datasheet because the datasheet is coming from kaggle which is a free source for the public and that data in the dataset is obtained from ClinicalTrials.gov site run by the government for public use.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# <b> What preprocessing/cleaning was done? (e.g., discretization or bucketing, tokenization, part-of-speech tagging, SIFT feature extraction, removal of instances, processing of missing values, etc.)<b>
#
# The creator of the dataset filtered raw data to include only trials relating to COVID-19. This was done by using keywords. They probably also handled missing values, column formatting, and removed duplicate data entries to make the dataset cleaner.
#
# <b>Was the “raw” data saved in addition to the preprocessed/cleaned data? (e.g., to support unanticipated future uses)<b>
#
# The “raw” data was not saved or shared on Kaggle. The final cleared and filtered CSV file is provided in the dataset. The original data can be obtained from the ClinicalTrials.gov, so the raw data can be acquired if need be.

# %% [markdown]
# ## Dataset Maintenance

# %% [markdown]
# <b>Who is supporting/hosting/maintaining the dataset? How does one contact the owner/curator/manager of the dataset (e.g. email address, or other contact info)?<b>
#
# The dataset is maintained by users of kaggle, but the data has not been updated in 5 years after being said that the data would be updated weekly.
#
# <b>Will the dataset be updated? How often and by whom? How will updates/revisions be documented and communicated (e.g., mailing list, GitHub)? Is there an erratum?<b>
#
# As said before, it was stated by the users that the dataset would be updated weekly but the last update has been 5 years ago now.
#
# <b>If the dataset becomes obsolete how will this be communicated?<b>
#
# We are unsure how we would know when the dataset will be obsolete so communication is not much
#
# <b>Is there a repository to link to any/all papers/systems that use this dataset?<b>
#
# There is no external repository for this Kaggle dataset that lists any links, systems, or  papers. This also goes for the government website.
#
# <b>If others want to extend/augment/build on this dataset, is there a mechanism for them to do so? <b>
#
# Yes, you can take the data from the government’s website or on Kaggle and then create your own dataset and add or change whatever you please.
#
# <b>If so, is there a process for tracking/assessing the quality of those contributions. What is the process for communicating/distributing these contributions to users?<b>
#
# No, there is no system to check the quality of new versions. Anyone can upload and update, and users must find and check these new files themselves.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# This stops a few warning messages from showing
pd.options.mode.chained_assignment = None 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#
# 5779  https://ClinicalTrials.gov/show/NCT04681339
# 5780  https://ClinicalTrials.gov/show/NCT04740229
# 5781  https://ClinicalTrials.gov/show/NCT04804917
# 5782  https://ClinicalTrials.gov/show/NCT04680000
#
# [5783 rows x 27 columns]

# %%
DF_Covid.shape
# Out:
# (5783, 27)

# %%
status = DF_Covid
mask = DF_Covid['Status'].value_counts().sort_values(ascending=False)

fig = px.histogram(
    DF_Covid,
    x='Status',
    category_orders={'Status': mask.index} 
)

fig.show()

# %%
fig = px.pie(DF_Covid, names = 'Study Type')

fig.update_traces(textposition='inside', textinfo='percent+label')

fig.show()

# %%
myCol = ['Funded Bys', 'Study Type','Age']
DF = DF_Covid[myCol]
ages = DF['Age'].unique()
show(ages)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_e5ae2448_ecd5_4b05_95e7_80e4904569f9"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_e5ae2448_ecd5_4b05_95e7_80e4904569f9:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>0</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"18 Years and older \\u00a0 (Adult, Older Adult)\"], [\"Child, Adult, Older Adult\"], [\"18 Years to 48 Years \\u00a0 (Adult)\"], [\"18 Years to 75 Years \\u00a0 (Adult, Older Adult)\"], [\"18 Years to 45 Years \\u00a0 (Adult)\"], [\"18 Years to 99 Years \\u00a0 (Adult, Older Adult)\"], [\"18 Years to 55 Years \\u00a0 (Adult)\"], [\"15 Years and older \\u00a0 (Child, Adult, Older Adult)\"], [\"18 Years to 80 Years \\u00a0 (Adult, Older Adult)\"], [\"45 Years and older \\u00a0 (Adult, Older Adult)\"], [\"20 Years to 100 Years \\u00a0 (Adult, Older Adult)\"], [\"8 Years to 88 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"5 Years to 65 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"up to 99 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"18 Years to 85 Years \\u00a0 (Adult, Older Adult)\"], [\"18 Years to 65 Years \\u00a0 (Adult, Older Adult)\"], [\"up to 29 Days \\u00a0 (Child)\"], [\"18 Years to 70 Years \\u00a0 (Adult, Older Adult)\"], [\"18 Years to 59 Years \\u00a0 (Adult)\"], [\"up to 100 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"20 Years to 60 Years \\u00a0 (Adult)\"], [\"40 Years to 80 Years \\u00a0 (Adult, Older Adult)\"], [\"23 Years and older \\u00a0 (Adult, Older Adult)\"], [\"18 Years to 120 Years \\u00a0 (Adult, Older Adult)\"], [\"16 Years and older \\u00a0 (Child, Adult, Older Adult)\"], [\"5 Years to 90 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"18 Years to 90 Years \\u00a0 (Adult, Older Adult)\"], [\"up to 18 Years \\u00a0 (Child, Adult)\"], [\"2 Years and older \\u00a0 (Child, Adult, Older Adult)\"], [\"70 Years and older \\u00a0 (Older Adult)\"], [\"18 Years to 26 Years \\u00a0 (Adult)\"], [\"18 Years to 95 Years \\u00a0 (Adult, Older Adult)\"], [\"12 Years and older \\u00a0 (Child, Adult, Older Adult)\"], [\"16 Years to 55 Years \\u00a0 (Child, Adult)\"], [\"30 Years to 70 Years \\u00a0 (Adult, Older Adult)\"], [\"35 Years to 65 Years \\u00a0 (Adult, Older Adult)\"], [\"18 Years to 40 Years \\u00a0 (Adult)\"], [\"18 Years to 60 Years \\u00a0 (Adult)\"], [\"18 Years to 100 Years \\u00a0 (Adult, Older Adult)\"], [\"6 Years and older \\u00a0 (Child, Adult, Older Adult)\"], [\"up to 17 Years \\u00a0 (Child)\"], [\"22 Years to 72 Years \\u00a0 (Adult, Older Adult)\"], [\"16 Years to 100 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"6 Months and older \\u00a0 (Child, Adult, Older Adult)\"], [\"20 Years to 65 Years \\u00a0 (Adult, Older Adult)\"], [\"14 Years to 75 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"5 Years and older \\u00a0 (Child, Adult, Older Adult)\"], [\"1 Year to 100 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"18 Years to 89 Years \\u00a0 (Adult, Older Adult)\"], [\"4 Years to 13 Years \\u00a0 (Child)\"], [\"16 Years to 90 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"1 Year to 90 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"6 Months to 100 Years \\u00a0 (Child, Adult, Older Adult)\"], [\"17 Years to 50 Years \\u00a0 (Child, Adult)\"], [\"18 Years to 69 Years \\u00a0 (Adult, Older Adult)\"], [\"19 Years and older \\u00a0 (Adult, Older Adult)\"], [\"18 Years to 50 Years \\u00a0 (Adult)\"], [\"8 Years and older \\u00a0 (Child, Adult, Older Adult)\"], [\"50 Years and older \\u00a0 (Adult, Older Adult)\"], [\"up to 20 Years \\u00a0 (Child, Adult)\"], [\"10 Years and older \\u00a0 (Child, Adult, Older Adult)\"], [\"18 Years to 49 Years \\u00a0 (Adult)\"], [\"18 Years to 62 Years \\u00a0 (Adult)\"], [\"18 Years to 67 Years \\u00a0 (Adult, Older Adult)\"], [\"40 Years and older \\u00a0 (Adult, Older Adult)\"], [\"up to 15 M ...

# %%
def categorize(ages):
    if pd.isna(ages):
        return "Unknown"
    age_clean = ages.replace('\xa0', ' ')
    
    has_child = "Child" in age_clean
    has_adult = "Adult" in age_clean and "Older Adult" not in age_clean
    has_older = "Older Adult" in age_clean

    if has_child and not has_adult and not has_older:
        return "Child Only"
    if has_adult and not has_child and not has_older:
        return "Adult Only"
    if has_older and not has_child and not has_adult:
        return "Older Adult Only"
    if has_child and has_adult and not has_older:
        return "Child + Adult"
    if has_adult and has_older and not has_child:
        return "Adult + Older Adult"
    return "Child + Adult + Older Adult"

DF['Age Category'] = DF['Age'].apply(categorize)

show(DF['Age Category'].value_counts())
show(DF)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_988cbca3_b10b_4389_b970_6efddfc0d2c6"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_988cbca3_b10b_4389_b970_6efddfc0d2c6:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>Age Category</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Older Adult Only\", 4437], [\"Child + Adult + Older Adult\", 805], [\"Adult Only\", 335], [\"Child + Adult\", 104], [\"Child Only\", 102]]"};
#         new ITable(table, dt_args);
#     });
# </script>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_66e1260f_dcef_41e9_828b_8d9c10445faa"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables
\"Observational\", \"18 Years and older \\u00a0 (Adult, Older Adult)\", \"Older Adult Only\"], [\"Other\", \"Observational\", \"18 Years and older \\u00a0 (Adult, Older Adult)\", \"Older Adult Only\"], [\"Other\", \"Observational\", \"18 Years and older \\u00a0 (Adult, Older Adult)\", \"Older Adult Only\"], [\"Other\", \"Interventional\", \"18 Years and older \\u00a0 (Adult, Older Adult)\", \"Older Adult Only\"], [\"Other\", \"Observational\", \"5 Years to 65 Years \\u00a0 (Child, Adult, Older Adult) ...

# %%
DF_counts = DF.groupby(['Study Type', 'Age Category', 'Funded Bys']).size().reset_index(name='Count')
DF_study = DF_counts[DF_counts['Study Type'].isin(['Interventional', 'Observational'])]

fig = px.bar(
    DF_study,
    x='Study Type',
    y='Count',
    color='Age Category',
    barmode='group'
)

fig.show()

# %%
DF_cond = DF_Covid.rename(columns={'Conditions': 'Condition'})
DF_cond['Condition'] = DF_cond['Condition'].str.strip()  # clean spaces

DF_cond.loc[
    DF_cond['Condition'].str.contains('covid|sars|corona|ncov', case=False, na=False),
    'Condition'
] = 'Covid'


DF_cond['Condition'] = DF_cond['Condition'].apply(lambda x: 'Covid' if x == 'Covid' else 'Other')
show(DF_cond['Condition'].value_counts())
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_524f3c95_455e_4707_afd7_c67529dcd3f9"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_524f3c95_455e_4707_afd7_c67529dcd3f9:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>Condition</th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Covid\", 4550], [\"Other\", 1233]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
DF_CS = DF_cond[DF_cond['Study Type'].isin(['Observational', 'Interventional'])]
DF_CS = DF_CS.groupby(['Condition', 'Study Type']).size().reset_index(name='Count')

fig = px.bar(
    DF_CS,
    x='Condition',
    y='Count',
    color='Study Type',
    barmode='group',
    title='Condition by Study Type'
)

fig.show()

# %%
DF = DF_Covid

DF.columns = DF.columns.str.strip()

DF['Enrollment'] = pd.to_numeric(DF['Enrollment'], errors='coerce')

DF['Condition'] = DF['Conditions'].astype(str).str.strip()

DF.loc[
    DF['Condition'].str.contains('covid|sars|corona|ncov', case=False, na=False),
    'Condition'
] = 'Covid'

# Everything else becomes "Other"
DF.loc[DF['Condition'] != 'Covid', 'Condition'] = 'Other'

def categorize(ages):
    if pd.isna(ages):
        return "Unknown"
    age_clean = ages.replace('\xa0', ' ')
    
    has_child = "Child" in age_clean
    has_adult = "Adult" in age_clean and "Older Adult" not in age_clean
    has_older = "Older Adult" in age_clean

    if has_child and not has_adult and not has_older:
        return "Child Only"
    if has_adult and not has_child and not has_older:
        return "Adult Only"
    if has_older and not has_child and not has_adult:
        return "Older Adult Only"
    if has_child and has_adult and not has_older:
        return "Child + Adult"
    if has_adult and has_older and not has_child:
        return "Adult + Older Adult"
    return "Child + Adult + Older Adult"

DF['Age Category'] = DF['Age'].apply(categorize)

df_age_total = DF.groupby('Age Category')['Enrollment'].sum().reset_index()

fig = px.bar(
    df_age_total,
    x='Age Category',
    y='Enrollment',
    title='Total Enrollment by Age Category'
)

fig.show()

# %%
DF_group = DF_Covid.groupby(['Age Category', 'Funded Bys']).size().reset_index(name='Count')

fig = px.bar(
    DF_group,
    x='Age Category',
    y='Count',
    color='Funded Bys',
    barmode='group',
    title='Funding Source by Age Category (Covid Only)'
)

fig.show()

# %%
def simplify_funder(f):
    if pd.isna(f) or f.strip() == "" or f.lower() == "unknown":
        return "Unknown"
    f = f.lower()
    if "industry" in f:
        return "Industry"
    if "nih" in f or "fed" in f or "federal" in f or "department" in f or "va" in f:
        return "Government"
    if "other" in f or "network" in f or "university" in f or "hospital" in f:
        return "Other Non-Profit / Academic"

    return "Other Non-Profit / Academic"

DF['Funding Category'] = DF['Funded Bys'].apply(simplify_funder)
df_group = DF.groupby(['Funding Category']).size().reset_index(name='Count')

fig = px.bar(
    df_group,
    x='Funding Category',
    y='Count',
    color='Funding Category',
    title='Simplified Funding Source for Older Adult Only (Covid Studies)'
)

fig.show()

# %%
DF = DF_Covid
DF.columns = DF.columns.str.strip()

DF['Enrollment'] = pd.to_numeric(DF['Enrollment'], errors='coerce')

DF['Condition'] = DF['Conditions'].astype(str).str.strip()

DF.loc[
    DF['Condition'].str.contains('covid|sars|corona|ncov', case=False, na=False),
    'Condition'
] = 'Covid'

DF.loc[DF['Condition'] != 'Covid', 'Condition'] = 'Other'

def categorize(age):
    if pd.isna(age):
        return "Unknown"
    
    age_clean = age.replace('\xa0', ' ')
    
    has_child = "Child" in age_clean
    has_adult = "Adult" in age_clean and "Older Adult" not in age_clean
    has_older = "Older Adult" in age_clean

    if has_child and not has_adult and not has_older:
        return "Child Only"
    if has_adult and not has_child and not has_older:
        return "Adult Only"
    if has_older and not has_child and not has_adult:
        return "Older Adult Only"
    if has_child and has_adult and not has_older:
        return "Child + Adult"
    if has_adult and has_older and not has_child:
        return "Adult + Older Adult"
    if has_child and has_adult and has_older:
        return "Child + Adult + Older Adult"
    
    return "Other"

DF['Age Category'] = DF['Age'].apply(categorize)

def simplify_funder(f):
    if pd.isna(f) or f.strip() == "" or f.lower() == "unknown":
        return "Unknown"
    
    f = f.lower()

    if "industry" in f:
        return "Industry"
    if "nih" in f or "fed" in f or "federal" in f or "department" in f or "va" in f:
        return "Government"
    if "other" in f or "network" in f or "university" in f or "hospital" in f:
        return "Other Non-Profit / Academic"
    
    return "Other Non-Profit / Academic"

DF['Funding Category'] = DF['Funded Bys'].apply(simplify_funder)

DF_filtered = DF[
    (DF['Condition'] == 'Covid') &
    (DF['Study Type'].isin(['Interventional', 'Observational']))
]

df_group = DF_filtered.groupby(['Age Category', 'Funding Category']).size().reset_index(name='Count')

fig = px.bar(
    df_group,
    x='Age Category',
    y='Count',
    color='Funding Category',
    barmode='group',
    title='Funding Source Across All Age Categories (Covid Only)'
)

fig.show()

# %% [markdown]
# ## Proposed Questions - Legal and Ethical Considerations

# %% [markdown]
# <b>What specific questions are you going to explore and present in the rest of the paper? Give a very brief overview of what you are going to do to answer those questions. Imagine this as a road map so your reader knows what to expect. If the dataset relates to people (e.g., their attributes) or was generated by people, were they informed about the data collection? (e.g., datasets that collect writing, photos, interactions, transactions, etc)<b>
#
# We want to know if the data that is used is being ethically obtained and done to show what is true with the data that we are shown. We do not want data that is solely for the benefit of someone else but for everyone. The data must also focus on a specific group while ignoring others while doing so
#
#
# <b>If it relates to other ethically protected subjects, have appropriate obligations been met? (e.g., medical data might include information collected from animals)<b>
#
# With the use of clinical trials in the mini data sheet we can see that we are only focusing on the data done by different countries about Covid-19
#
# <b>If it relates to people, were there any ethical review applications/reviews/approvals? (e.g. Institutional Review Board applications)<b>
#
# With people being tested about covid and each instance of the dataset being its own testing. We can see that each person that comes into this dataset has gone through approvals and willingly to join the study.
#
# <b>If it relates to people, were they told what the dataset would be used for and did they consent? What community norms exist for data collected from human communications? If consent was obtained, how? Were the people provided with any mechanism to revoke their consent in the future or for certain uses?<b>
#
# In terms of permission used in the dataset, we can not say that they were not given permission by each individual but since the data is coming from a free access database from the government, the person may have suspected that they were going to be taken in put into other datasets for the purpose of review
#
#
# <b>If it relates to people, could this dataset expose people to harm or legal action? (e.g., financial, social or otherwise) What was done to mitigate or reduce the potential for harm? <b>
#
# There are some things that can maybe harm or cause legal action for the individual in the studies and that is from who is funding all the different instances. Each instance we can see shows who may fund each project and a majority of those funding is non profits which sometimes can be problematic since there aren't many regulations with non profits unlike stuff funded by the government.
#
# <b>If it relates to people, does it unfairly advantage or disadvantage a particular social group? In what ways? How was this mitigated? <b>
#
# What we see in the data is that a majority of the studies are done to older people for Covid. You may say that is because they tend to be more prone to dangerous risks with covid but with little down to the other age groups may lead to different affects since older adults are typically much more senstive to a younger adult or even a child.
#
# <b>If it relates to people, were they provided with privacy guarantees? If so, what guarantees and how are these ensured?<b>
#
# Privacy is something very important we want to answer especially when we talk about things being ethical and we can see in the dataset that each trial does not give personal information to the public that we do not want to see out to be accessed freely.
#
# <b>Does the dataset comply with the EU General Data Protection Regulation (GDPR)? Does it comply with any other standards, such as the US Equal Employment Opportunity Act?<b>
#
# No, due to this very vague fact from the GDPR, "Transfers to non-EU countries. The GDPR also covers the transfer of personal data to non-EU countries and international organisations. The European Commission is in charge of assessing the level of protection given by a territory or processing sector in a non-EU country. Where the Commission has not taken an adequacy decision on a territory or sector, transfer of personal data may still take place in particular cases or when there are appropriate safeguards in place" which means that the patient may not have given permission to give their study information to other countries outside the EU to use that information as well as the investigators names are also in the trials of who uploaded the data but since some are in the EU then they should be protected by that right from the GDPR of personal information and even their name.
#
# <b>Does the dataset contain information that might be considered sensitive or confidential? (e.g., personally identifying information)<b>
# No the data does not contain anything sensitive as said before that privacy is important and none of the information that is sensitive that gives patients information to the public
#
# <b>Does the dataset contain information that might be considered inappropriate or offensive?<b>
#
# None of the information in the dataset has anything inappropriate or offensive as it is a clinical trial that is professionally done.

# %% [markdown]
# ## Analysis and Results

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We achieved analyzing and discovering the background of the dataset from Kaggle. Learning that it is merely a subpart of a whole lot of data coming from a government funded website. We learned how and what processes the data was obtained from and whether or not it was ethical. A limitation that we went through is that there are missing data points within our initial dataset. Another is that the initial website is within a certain time stamp while the government database is constantly updating itself. If we had more time and money to keep going, we would continue to analyze different clinical trials referencing the same datasheet format to see if Microsoft has provided reliable items for datasets.
